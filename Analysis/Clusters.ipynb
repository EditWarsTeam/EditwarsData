# %% [markdown]
# Step 1. Install lib

# %%
import pandas as pd
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from sentence_transformers import SentenceTransformer
import nltk
import re
from nltk.corpus import stopwords
from hdbscan import HDBSCAN
from umap import UMAP
import pymorphy2
from nltk import word_tokenize   

class LemmaTokenizer:
    def __init__(self):
        self.wnl = pymorphy2.MorphAnalyzer()
    def __call__(self, doc):
        return [self.wnl.parse(t)[0].normal_form for t in word_tokenize(doc)]

nltk.download('stopwords')
stopWords = stopwords.words("russian")

import nltk
nltk.download('punkt')

# %% [markdown]
# Step 2. Dump dataset with headlines

# %%
df = pd.read_csv('PATH/df_result.csv') # read df_result.csv

# def change_title(text):
#   return re.sub('[^А-яЁёA-z]', ' ', text.lower())
# df['title_new'] = df['title_new'].apply(change_title)
# def change_time(dt):
#     dt_new = dt[0:10]
#     return datetime.strptime(dt_new, '%Y-%m-%d')
# df['title_new'] = df['title_new'].fillna(df['page_title'])
# df = df.dropna()
# df['fetchdate_check'] = df['fetchdate_check'].apply(change_time)
# df['fetchdate_orig'] = df['fetchdate_orig'].apply(change_time)
# df.drop_duplicates(subset=['title_new', 'page_domain_root'],keep='first',inplace=True)
# df_result = df.reset_index().drop(columns = ['Unnamed: 0', 'index'],axis = 1)
# df_result.to_csv("cleaned_data.csv")
# df_result.to_csv("df_result.csv")

titles = df.title_new.to_list()   
timestamps = df.fetchdate_orig.to_list()

# %% [markdown]
# Step 3. Learn Bertopic model. Skip this step if the model had existed.

# %%
sentence_model = SentenceTransformer("paraphrase-multilingual-mpnet-base-v2")

hdbscan_model = HDBSCAN(min_cluster_size=200, metric='euclidean', 
                        cluster_selection_method='eom', prediction_data=True, min_samples=3)

umap_model = UMAP(n_neighbors=15, n_components=10, metric='cosine', low_memory=False, random_state=17)


topic_model = BERTopic(embedding_model=sentence_model, diversity=0.3, hdbscan_model=hdbscan_model, umap_model=umap_model,  top_n_words=30, nr_topics="auto", verbose=True,)
topics, probs = topic_model.fit_transform(titles)

vectorizer_model = CountVectorizer(ngram_range=(1, 3), stop_words=stopWords, tokenizer=LemmaTokenizer(), min_df=15)

topic_model.update_topics(titles, topics, vectorizer_model=vectorizer_model)


with open("topics.txt", "w") as f:
    for t in topics:
        f.write(str(t) +"\n")

topic_model.save("model")

# %% [markdown]
# Step 4. Load model and merge the topics

# %%
topic_model = BERTopic.load("PATH/model") # import model 

topics = []
with open("PATH/topics.txt", "r") as f:
  for line in f:
    topics.append(int(line.strip()))

# %%
"""Get data with the list of topics"""
df = topic_model.get_topic_info()
# df.to_csv("list_topics.csv")

# %%
"""Collect info about topic in united DataFrame"""

import numpy as np
def _clean_tuples(series: pd.Series) -> pd.Series:
    series[series.str[0] == ""] = np.nan
    return series

def get_topics() -> pd.DataFrame:
    """Get all topics with top words and their scores."""
    df1 = pd.DataFrame.from_dict(md.get_topics()).T.add_prefix("word_score_")
    df1.reset_index(inplace=True)
    df1.rename(columns={"index": "Topic"}, inplace=True)
    tuple_cols = df1.filter(like="word_score_").columns
    df1[tuple_cols] = df1[tuple_cols].apply(_clean_tuples)
    return df1

def represent() -> pd.DataFrame:
    representative_docs = md.get_representative_docs()
    dict_r = {}
    for k, v in representative_docs.items():
        dict_r[str(k)] = re.sub('[^А-яЁёA-z0-9,.:"?! ]', '', str(v))
    df_r = pd.DataFrame.from_dict(dict_r, orient='index').reset_index()
    df_r = df_r.rename(columns={"index": "Topic", 0: "Headlines"})
    return df_r

def unite() -> pd.DataFrame:
    temp = pd.merge(df, get_topics(), on=['Topic'])
    temp["Topic"] = temp["Topic"].astype(str)
    result_df = pd.merge(temp, represent(), on=['Topic'])
    result_df.to_csv("info_topics.csv")
    # result_df.to_json("info_topics.json")

unite()

# %%
"""Get data with all headlines in topics"""
df = pd.DataFrame({'topic': topics, 'document': titles})
df[df.topic > 0].reset_index().sort_values(by="topic")[["topic", "document"]].to_csv("all_headlines.csv")

# %% [markdown]
# Step 5. Visualise topics over time

# %%
topics_over_time = topic_model.topics_over_time(titles, topics, timestamps, nr_bins=30)
topics_over_time.to_csv("topics_over_time.csv")

# %%
import pandas as pd
topics_over_time = pd.read_csv('PATH/topics_over_time.csv') # read topics_over_time.csv on google drive

# %%
import datetime as dt
topics_over_time["Timestamp"] = topics_over_time["Timestamp"].dt.to_period("D")

# %%
topics_over_time.to_csv("time.csv")

# %%
topics_over_time.loc[(topics_over_time['Topic'] == 0) & (topics_over_time['Topic'] == 1)]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Topic, Words, Frequency, Timestamp]
# Index: []

# %% [markdown]
# Narrative #14 Goals and terms of special operation

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [94, 99, 145, 181, 193])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="0583a72d-8e0b-49d5-bba0-7bd7b308ec7d" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0583a72d-8e0b-49d5-bba0-7bd7b308ec7d")) {                    Plotly.newPlot(                        "0583a72d-8e0b-49d5-bba0-7bd7b308ec7d",                        [{"hoverinfo":"text","hovertext":["<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u043f\u0440\u0438\u0433\u043e\u0436\u0438\u043d, \u043f\u043e\u0434\u0430\u0442\u044c \u0437\u0430\u044f\u0432\u043b\u0435\u043d\u0438\u0435, \u044e\u0433\u043e \u0432\u043e\u0441\u0442\u043e\u043a, \u0432\u043e\u0441\u0442\u043e\u043a \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u043d\u0430\u0440\u043e\u0434, \u0431\u0435\u043b\u043e\u0440\u0443\u0441\u0441\u043a\u0438\u0439, \u043f\u043e\u0434\u043f\u0438\u0441\u0430\u0442\u044c \u0437\u0430\u043a\u043e\u043d, \u0440\u0430\u0441\u0441\u043b\u0435\u0434\u043e\u0432\u0430\u043d\u0438\u0435 \u0434\u0435\u043b\u043e","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u0440\u0430\u0441\u0441\u043a\u0430\u0437\u0430\u0442\u044c \u0440\u043e\u043b\u044c, \u0437\u0430\u044f\u0432\u0438\u0442\u044c \u043b\u0443\u043a\u0430\u0448\u0435\u043d\u043a\u043e, \u0441\u0442\u0430\u0442\u044c \u0447\u0430\u0441\u0442\u044b\u0439, \u0446\u0430\u0440","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u043d\u0430\u0440\u043e\u0434, \u044d\u0442\u043e \u043d\u0430\u0447\u0430\u043b\u043e, \u0441\u043f\u0430\u0441\u0438\u0442\u0435\u043b\u044c, \u0437\u0435\u0440\u043a\u0430\u043b\u043e","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u043d\u0430\u0440\u043e\u0434, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439, \u043f\u0430\u043c\u044f\u0442\u044c, \u0436\u0435\u0440\u0442\u0432\u0430","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u0443\u043a\u0440\u0430\u0438\u043d\u0441\u043a\u0438\u0439 \u043d\u0430\u0440\u043e\u0434, \u0434\u0435\u043f\u0443\u0442\u0430\u0442 \u0440\u0430\u0434\u0430, \u0440\u0430\u0434\u0430, \u043d\u0430\u0440\u043e\u0434","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u043d\u0430\u0440\u043e\u0434, \u0441\u0443\u0434, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439, \u0440\u043e\u0441\u0442\u043e\u0432\u0441\u043a\u0438\u0439","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u0434\u043e\u043d\u0431\u0430\u0441\u0441, \u043f\u0440\u043e\u0438\u0441\u0445\u043e\u0434\u0438\u0442\u044c, \u0446\u0438\u043d\u0438\u0437\u043c, \u0441\u043b\u043e\u0432\u043e","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u0434\u043e\u043d\u0431\u0430\u0441\u0441, \u0433\u0435\u043d\u0441\u0435\u043a \u043e\u043e\u043d, \u043d\u0430\u0440\u043e\u0434, \u043f\u0440\u043e\u0438\u0441\u0445\u043e\u0434\u0438\u0442\u044c","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u043f\u0443\u0442\u0438\u043d \u043d\u0430\u043f\u043e\u043c\u043d\u0438\u0442\u044c, \u043d\u0430\u043f\u043e\u043c\u043d\u0438\u0442\u044c, \u0433\u043b\u0430\u0437, \u0437\u0430\u043a\u0440\u044b\u0432\u0430\u0442\u044c","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u0440\u0430\u0441\u0441\u043a\u0430\u0437\u0430\u0442\u044c \u043f\u043e\u0437\u0438\u0446\u0438\u044f, \u0440\u043e\u0441\u0442\u043e\u0432\u0441\u043a\u0438\u0439 \u043e\u0431\u043b\u0430\u0441\u0442\u044c, \u0440\u043e\u0441\u0442\u043e\u0432\u0441\u043a\u0438\u0439, \u043e\u0431\u0449\u0435\u0441\u0442\u0432\u0435\u043d\u043d\u0438\u043a","<b>Topic 94</b><br>Words: \u0433\u0435\u043d\u043e\u0446\u0438\u0434, \u0438\u0437\u0431\u0 ...

# %% [markdown]
# Narrative #13 Preparation to the war

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [12, 33])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ec6b50a7-c338-47c3-bb48-60ed7e6b539c" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ec6b50a7-c338-47c3-bb48-60ed7e6b539c")) {                    Plotly.newPlot(                        "ec6b50a7-c338-47c3-bb48-60ed7e6b539c",                        [{"hoverinfo":"text","hovertext":["<b>Topic 12</b><br>Words: \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u043e\u0439\u043d\u0430 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043f\u0440\u043e\u0432\u043e\u043a\u0430\u0446\u0438\u044f, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435, \u0441\u0446\u0435\u043d\u0430\u0440\u0438\u0439","<b>Topic 12</b><br>Words: \u043a\u043e\u043d\u0444\u043b\u0438\u043a\u0442, \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u043e\u0435\u043d\u043d\u044b\u0439 \u043a\u043e\u043d\u0444\u043b\u0438\u043a\u0442, \u0443\u043a\u0440\u0430\u0438\u043d\u0430 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043f\u043e\u043b\u0438\u0442\u043e\u043b\u043e\u0433","<b>Topic 12</b><br>Words: \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435 \u0440\u043e\u0441\u0441\u0438\u044f \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435 \u0440\u043e\u0441\u0441\u0438\u044f, \u043f\u0440\u0435\u0434\u043b\u043e\u0433","<b>Topic 12</b><br>Words: \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435, \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0441\u0446\u0435\u043d\u0430\u0440\u0438\u0439, \u043b\u044e\u0431\u043e\u0439 \u043c\u043e\u043c\u0435\u043d\u0442, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435 \u0440\u043e\u0441\u0441\u0438\u044f","<b>Topic 12</b><br>Words: \u0432\u043e\u0439\u043d\u0430 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435, \u0432\u043e\u043a\u0440\u0443\u0433 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u043e\u043a\u0440\u0443\u0433","<b>Topic 12</b><br>Words: \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u043e\u0439\u043d\u0430 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u043e\u0439\u043d\u0430","<b>Topic 12</b><br>Words: \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435, \u043d\u0430\u0440\u044b\u0448\u043a\u0438\u043d, \u0432\u043e\u0439\u043d\u0430, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 12</b><br>Words: \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u043e\u043a\u0440\u0443\u0433 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u043e\u0439\u043d\u0430 \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 12</b><br>Words: \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043a\u043e\u043d\u0444\u043b\u0438\u043a\u0442, \u0432\u0442\u043e\u0440\u0436\u0435\u043d\u0438\u0435, \u0441\u0438\u0442\u0443\u0430\u0446\u0438\u044f \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043a\u043e\u043d\u0444\u043b\u0438\u043a\u0442 \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 12</b><br>Words: \u043a\u043e\u043d\u0444\u043b\u0438\u043a\u0442 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043a\u043e\u043d\u0444\u043b\u0438\u043a\u0442, \u0441\u0438\u0442\u0443\u0430\u0446\u0438\u044f \u0443\u043a\u0440\u0430\u0 ...

# %% [markdown]
# Narrative #3-4 Military actions

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [0, 25, 31, 64, 80, 106, 113, 118, 144, 158, 164, 175, 225, 230])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="13cb9eaf-35e4-4ea1-b354-a119f2a027c4" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13cb9eaf-35e4-4ea1-b354-a119f2a027c4")) {                    Plotly.newPlot(                        "13cb9eaf-35e4-4ea1-b354-a119f2a027c4",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u043f\u0443\u0442\u0438\u043d \u0431\u0430\u0439\u0434\u0435\u043d, \u0433\u0430\u0437, \u0442\u0440\u0430\u043d\u0437\u0438\u0442, \u0432\u0437\u0440\u044b\u0432, \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f","<b>Topic 0</b><br>Words: \u0442\u0440\u0430\u043d\u0437\u0438\u0442, \u0433\u0430\u0437, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u0433\u0430\u0437, \u0432\u043e\u0440\u043e\u0432\u0441\u0442\u0432\u043e, \u0441\u043b\u043e\u0432\u0430\u043a\u0438\u044f","<b>Topic 0</b><br>Words: \u0447\u0435\u043c\u043f\u0438\u043e\u043d\u0430\u0442, \u0444\u0438\u0433\u0443\u0440\u0438\u0441\u0442, \u0432\u043d\u0435\u0437\u0430\u043f\u043d\u044b\u0439, \u0432\u0437\u0440\u044b\u0432, \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f","<b>Topic 0</b><br>Words: \u0431\u043b\u0438\u043d\u043a\u0435\u043d, \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u043f\u043e\u0440\u043e\u0448\u0435\u043d\u043a\u043e, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u043b\u0430\u0432\u0440\u043e\u0432, \u043b\u0430\u0432\u0440\u043e\u0432","<b>Topic 0</b><br>Words: \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u0434\u0436\u043e\u043d\u0441\u043e\u043d, \u0432\u0435\u043b\u0438\u043a\u043e\u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0433\u043b\u0430\u0432\u0430","<b>Topic 0</b><br>Words: \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u0434\u0436\u043e\u043d\u0441\u043e\u043d, \u043c\u0430\u043a\u0440\u043e\u043d, \u043f\u0443\u0442\u0438\u043d \u043c\u0430\u043a\u0440\u043e\u043d, \u0442\u0440\u0430\u043d\u0437\u0438\u0442","<b>Topic 0</b><br>Words: \u043c\u0430\u043a\u0440\u043e\u043d, \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u043f\u0443\u0442\u0438\u043d \u043c\u0430\u043a\u0440\u043e\u043d, \u0432\u0441\u0442\u0440\u0435\u0447\u0430, \u0432\u0435\u043b\u0438\u043a\u043e\u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f","<b>Topic 0</b><br>Words: \u043e\u0431\u0441\u0442\u0440\u0435\u043b, \u0432\u0437\u0440\u044b\u0432, \u043e\u0431\u0441\u0442\u0440\u0435\u043b\u044f\u0442\u044c, \u043b\u0443\u0433\u0430\u043d\u0441\u043a, \u0434\u043e\u043d\u0431\u0430\u0441\u0441","<b>Topic 0</b><br>Words: \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f, \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043e\u0431\u0441\u0442\u0440\u0435\u043b, \u043e\u0431\u0441\u0442\u0440\u0435\u043b\u044f\u0442\u044c, \u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f","<b>Topic 0</b><br>Words: \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f, \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u043e\u0435\u043d\u043d\u044b\u0439, \u043c\u0438\u043d\u043e\u0431\u043e\u0440\u043e\u043d\u044b","<b>Topic 0</b><br>Words: \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f, \u043f\u043e\u0433\u0438\u0431\u043d\u0443\u0442\u044c, \u043e\u0431\u0441\u0442\u0440\u0435\u043b\u044f\u0442\u044c, \u0432\u0440\u0435\u043c\u044f \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f","<b>Topic 0</b><br> ...

# %% [markdown]
# Narrative #10 Negotiations

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [14, 57, 61, 104, 110, 159, 207])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6d57ee15-76f0-4a65-906e-78b540cc79e7" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d57ee15-76f0-4a65-906e-78b540cc79e7")) {                    Plotly.newPlot(                        "6d57ee15-76f0-4a65-906e-78b540cc79e7",                        [{"hoverinfo":"text","hovertext":["<b>Topic 14</b><br>Words: \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0440\u043e\u0441\u0441\u0438\u044f, \u043f\u0440\u043e\u0432\u0435\u0441\u0442\u0438 \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0440\u043e\u0441\u0441\u0438\u044f \u0441\u0448\u0430","<b>Topic 14</b><br>Words: \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0440\u043e\u0441\u0441\u0438\u044f, \u043a\u0443\u043b\u0435\u0431, \u043c\u0438\u043d\u0441\u043a\u0438\u0439 \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u043c\u0438\u043d\u0441\u043a\u0438\u0439","<b>Topic 14</b><br>Words: \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0440\u043e\u0441\u0441\u0438\u044f, \u0434\u0438\u0430\u043b\u043e\u0433, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0440\u043e\u0441\u0441\u0438\u044f \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 14</b><br>Words: \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u043c\u0438\u043d\u0441\u043a\u0438\u0439, \u043c\u0438\u043d\u0441\u043a\u0438\u0439 \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u0432\u043e\u043a\u0440\u0443\u0433 \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 14</b><br>Words: \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u043c\u0438\u043d\u0441\u043a\u0438\u0439, \u043c\u0438\u043d\u0441\u043a\u0438\u0439 \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0440\u043e\u0441\u0441\u0438\u044f, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 14</b><br>Words: \u043c\u0438\u043d\u0441\u043a\u0438\u0439, \u043c\u0438\u043d\u0441\u043a\u0438\u0439 \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0440\u043e\u0441\u0441\u0438\u044f","<b>Topic 14</b><br>Words: \u043c\u0438\u043d\u0441\u043a\u0438\u0439 \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u043c\u0438\u043d\u0441\u043a\u0438\u0439, \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 14</b><br>Words: \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u043c\u0438\u043d\u0441\u043a\u0438\u0439 \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u043c\u0438\u043d\u0441\u043a\u0438\u0439, \u0441\u043e\u0433\u043b\u0430\u0448\u0435\u043d\u0438\u0435, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 14</b><br>Words: \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u ...

# %% [markdown]
# Narrative #5 Russia-defender

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [1, 90, 95, 96, 112, 117, 122, 161, 178, 183, 194, 213, 228])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="39bf3c74-0167-4f3f-888a-7b0f91f7acfc" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("39bf3c74-0167-4f3f-888a-7b0f91f7acfc")) {                    Plotly.newPlot(                        "39bf3c74-0167-4f3f-888a-7b0f91f7acfc",                        [{"hoverinfo":"text","hovertext":["<b>Topic 1</b><br>Words: \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439 \u043f\u043e\u043c\u043e\u0449\u044c, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439, \u0442\u043e\u043d\u043d\u0430, \u0431\u0435\u0436\u0435\u043d\u0435\u0446, \u043a\u0443\u0431\u0430","<b>Topic 1</b><br>Words: \u0434\u043e\u0431\u0440\u043e\u0432\u043e\u043b\u044c\u043d\u044b\u0439, \u0430\u043b\u043c\u0430 \u0430\u0442\u0430, \u0430\u0442\u0430, \u0430\u043b\u043c\u0430, \u0433\u0435\u043d\u043a\u043e\u043d\u0441\u0443\u043b\u044c\u0441\u0442\u0432\u043e","<b>Topic 1</b><br>Words: \u044d\u0432\u0430\u043a\u0443\u0438\u0440\u043e\u0432\u0430\u0442\u044c, \u0431\u0435\u0436\u0435\u043d\u0435\u0446, \u044d\u0432\u0430\u043a\u0443\u0430\u0446\u0438\u044f, \u0441\u0438\u0431\u0438\u0440\u044c, \u0436\u0438\u0442\u0435\u043b\u044c \u0441\u0448\u0430","<b>Topic 1</b><br>Words: \u0431\u0435\u0436\u0435\u043d\u0435\u0446, \u044d\u0432\u0430\u043a\u0443\u0438\u0440\u043e\u0432\u0430\u0442\u044c, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439 \u043f\u043e\u043c\u043e\u0449\u044c, \u043c\u0438\u043d\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435","<b>Topic 1</b><br>Words: \u0431\u0435\u0436\u0435\u043d\u0435\u0446, \u044d\u0432\u0430\u043a\u0443\u0430\u0446\u0438\u044f, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439 \u043f\u043e\u043c\u043e\u0449\u044c, \u043f\u043e\u043c\u043e\u0449\u044c","<b>Topic 1</b><br>Words: \u0431\u0435\u0436\u0435\u043d\u0435\u0446, \u044d\u0432\u0430\u043a\u0443\u0438\u0440\u043e\u0432\u0430\u0442\u044c, \u0431\u0435\u0436\u0435\u043d\u0435\u0446 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043c\u0438\u043d\u0438\u0440\u043e\u0432\u0430\u043d\u0438\u0435, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439","<b>Topic 1</b><br>Words: \u0431\u0435\u0436\u0435\u043d\u0435\u0446, \u043e\u0431\u0441\u0435, \u044d\u0432\u0430\u043a\u0443\u0430\u0446\u0438\u044f, \u0431\u0435\u0436\u0435\u043d\u0435\u0446 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043f\u043e\u043a\u0438\u0434\u0430\u0442\u044c","<b>Topic 1</b><br>Words: \u0431\u0435\u0436\u0435\u043d\u0435\u0446, \u0431\u0435\u0436\u0435\u043d\u0435\u0446 \u0434\u043e\u043d\u0431\u0430\u0441\u0441, \u0434\u043e\u043d\u0431\u0430\u0441\u0441, \u044d\u0432\u0430\u043a\u0443\u0438\u0440\u043e\u0432\u0430\u0442\u044c, \u044d\u0432\u0430\u043a\u0443\u0430\u0446\u0438\u044f","<b>Topic 1</b><br>Words: \u0431\u0435\u0436\u0435\u043d\u0435\u0446, \u0431\u0435\u0436\u0435\u043d\u0435\u0446 \u0434\u043e\u043d\u0431\u0430\u0441\u0441, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439, \u0434\u043e\u043d\u0431\u0430\u0441\u0441, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439 \u043f\u043e\u043c\u043e\u0449\u044c","<b>Topic 1</b><br>Words: \u0431\u0435\u0436\u0435\u043d\u0435\u0446, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439, \u0433\u0443\u043c\u0430\u043d\u0438\u0442\u0430\u0440\u043d\u044b\u0439 \u043f\u043e\u043c\u043e\u0449\u044c, \u043f\u043e\u043c\u043e\u0449\u044c, \u0431\u0435\u0436\u0435\u043d\u0435\u0446 \u0434\u043e\u043d\u0431\u0430\u0441\u0441","<b>Topic 1</b><br>Words: \u ...

# %% [markdown]
# Narrative #6 Inner enemies

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [91, 136, 157, 160])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="b6fe1d39-b084-4db8-8f73-577990e1efdb" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b6fe1d39-b084-4db8-8f73-577990e1efdb")) {                    Plotly.newPlot(                        "b6fe1d39-b084-4db8-8f73-577990e1efdb",                        [{"hoverinfo":"text","hovertext":["<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439, \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439 \u043a\u0430\u0437\u043d\u044c, \u043a\u0430\u0437\u043d\u044c, \u0432\u043e\u0437\u0432\u0440\u0430\u0449\u0435\u043d\u0438\u0435, \u043c\u043e\u0440\u0430\u0442\u043e\u0440\u0438\u0439","<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439, \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439 \u043a\u0430\u0437\u043d\u044c, \u043a\u0430\u0437\u043d\u044c, \u043c\u043e\u0440\u0430\u0442\u043e\u0440\u0438\u0439, \u0440\u043f\u0446","<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439, \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439 \u043a\u0430\u0437\u043d\u044c, \u043a\u0430\u0437\u043d\u044c, \u043d\u0435\u0432\u043e\u0437\u043c\u043e\u0436\u043d\u044b\u0439, \u0442\u0443\u043d\u0438\u0441","<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439, \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439 \u043a\u0430\u0437\u043d\u044c, \u043a\u0430\u0437\u043d\u044c, \u0437\u0430\u043a\u043b\u044e\u0447\u0438\u0442\u044c, \u043e\u0442\u043c\u0435\u043d\u0438\u0442\u044c","<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439, \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439 \u043a\u0430\u0437\u043d\u044c, \u043a\u0430\u0437\u043d\u044c, \u043f\u0440\u0438\u0433\u043e\u0432\u043e\u0440\u0438\u0442\u044c, \u0443\u0431\u0438\u0439\u0441\u0442\u0432\u043e","<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439, \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439 \u043a\u0430\u0437\u043d\u044c, \u043a\u0430\u0437\u043d\u044c, \u0444\u0431\u0440, \u043f\u0440\u0438\u0431\u043b\u0438\u0437\u0438\u0442\u044c","<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u0435\u043b\u044c\u043d\u044b\u0439, \u043f\u0440\u0438\u0433\u043e\u0432\u043e\u0440, \u0440\u043e\u0441\u0441\u0438\u044f \u043a\u0438\u0442\u0430\u0439, \u043f\u043e\u0441\u0442\u0430\u0432\u0438\u0442\u044c, \u043f\u043e\u0434\u043f\u0438\u0441\u0430\u0442\u044c","<b>Topic 91</b><br>Words: \u0441\u0432\u043e\u0431\u043e\u0434\u0430, \u043f\u043b\u0430\u0442\u0438\u0442\u044c, \u0441\u0447\u0438\u0442\u0430\u0442\u044c \u0441\u0448\u0430, \u0434\u0430\u043d\u0438\u043b\u043e\u0432, \u0437\u0430\u0449\u0438\u0442\u0430","<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439, \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439 \u043a\u0430\u0437\u043d\u044c, \u043a\u0430\u0437\u043d\u044c, \u043c\u043e\u0440\u0430\u0442\u043e\u0440\u0438\u0439, \u0441\u043f\u0447","<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439, \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439 \u043a\u0430\u0437\u043d\u044c, \u043a\u0430\u0437\u043d\u044c, \u0433\u043b\u0430\u0432\u0430 \u0441\u043f\u0447, \u0432\u043e\u0437\u0432\u0440\u0430\u0449\u0435\u043d\u0438\u0435","<b>Topic 91</b><br>Words: \u0438\u0437\u0431\u0435\u0436\u0430\u0442\u044c, \u043d\u0430\u043a\u0430\u0437\u0430\u043d\u0438\u0435, \u0434\u0435\u043f\u0443\u0442\u0430\u0442 \u0433\u043e\u0441\u0434\u0443\u043c\u0430, \u043f\u043e\u043c\u043e\u0447\u044c, \u0443\u0431\u0438\u0439\u0441\u0442\u0432\u043e","<b>Topic 91</b><br>Words: \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439, \u0441\u043c\u0435\u0440\u0442\u043d\u044b\u0439 \u043a\u0430\u0437\u043d\u044c, \u043a\u0430\u0437\u043d\u044c, \u043b\u0434\ ...

# %% [markdown]
# Narrative #11 Russian allies

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [6, 13, 38, 85, 92, 100, 149, 174, 216])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="103bac37-6590-4299-9255-a3070736bac7" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("103bac37-6590-4299-9255-a3070736bac7")) {                    Plotly.newPlot(                        "103bac37-6590-4299-9255-a3070736bac7",                        [{"hoverinfo":"text","hovertext":["<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0440\u043e\u0441\u0441\u0438\u044f \u043a\u0438\u0442\u0430\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u0441\u0442\u0430\u043d\u0446\u0438\u044f, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0441\u0438, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d, \u0441\u0438 \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d, \u0441\u0438 \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u043d\u043e\u0432\u044b\u0439 \u0433\u043e\u0434, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d, \u0441\u0438, \u0441\u0438 \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d, \u0440\u043e\u0441\u0441\u0438\u044f \u043a\u0438\u0442\u0430\u0439","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0440\u043e\u0441\u0441\u0438\u044f \u043a\u0438\u0442\u0430\u0439, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0440\u043e\u0441\u0441\u0438\u044f \u043a\u0438\u0442\u0430\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u0441\u0438","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d, \u0441\u0438 \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d, \u0441\u0438 \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u043f\u0435\u043a\u0438\u043d, \u043a\u043d\u0440","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u0441\u0438 \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d, \u0446\u0437\u0438\u043d\u044c\u043f\u0438\u043d, \u0441\u0438, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0439\u0441\u043a\u0438\u0439, \u0442\u0430\u0439\u0432\u0430\u043d\u044c, \u0440\u043e\u0441\u0441\u0438\u044f \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0435\u0446","<b>Topic 6</b><br>Words: \u043a\u0438\u0442\u0430\u0439, \u043a\u0438\u0442\u0430\u0439 ...

# %% [markdown]
# Narrative #2 Nedogosudarstvo

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [2, 60, 135, 166])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="528ea0fe-6d71-40ba-96ca-b93574886add" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("528ea0fe-6d71-40ba-96ca-b93574886add")) {                    Plotly.newPlot(                        "528ea0fe-6d71-40ba-96ca-b93574886add",                        [{"hoverinfo":"text","hovertext":["<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u043e\u0444\u0438\u0441 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u043e\u0444\u0438\u0441, \u0443\u043a\u0440\u0430\u0438\u043d\u0430 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u043f\u043e\u0440\u043e\u0448\u0435\u043d\u043a\u043e","<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0431\u0430\u0439\u0434\u0435\u043d, \u0440\u0430\u0437\u0433\u043e\u0432\u043e\u0440, \u043e\u0444\u0438\u0441 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0437\u0435\u043b\u0451\u043d\u044b\u0439","<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u043c\u0438\u0445\u0430\u0438\u043b, \u0442\u0435\u043b\u0435\u0432\u0435\u0434\u0443\u0449\u0438\u0439, \u0441\u043c\u0435\u0440\u0442\u044c, \u0443\u043c\u0435\u0440\u0435\u0442\u044c","<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u043f\u043e\u0440\u043e\u0448\u0435\u043d\u043a\u043e, \u043e\u0444\u0438\u0441 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u043e\u0444\u0438\u0441, \u043c\u0438\u0445\u0430\u0438\u043b","<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439 \u0437\u0430\u044f\u0432\u0438\u0442\u044c, \u0443\u043a\u0440\u0430\u0438\u043d\u0430 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0431\u0430\u0439\u0434\u0435\u043d, \u0432\u043b\u0430\u0434\u0438\u043c\u0438\u0440 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439","<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439 \u0437\u0430\u044f\u0432\u0438\u0442\u044c, \u0434\u0436\u043e\u043d\u0441\u043e\u043d, \u0432\u0441\u0442\u0440\u0435\u0447\u0430, \u0443\u043a\u0440\u0430\u0438\u043d\u0430 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439","<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0443\u043a\u0440\u0430\u0438\u043d\u0430 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u043c\u0430\u043a\u0440\u043e\u043d, \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439 \u0437\u0430\u044f\u0432\u0438\u0442\u044c, \u043e\u0444\u0438\u0441 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439","<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0443\u043a\u0440\u0430\u0438\u043d\u0430 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439 \u0437\u0430\u044f\u0432\u0438\u0442\u044c, \u043e\u0444\u0438\u0441 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u043e\u0444\u0438\u0441","<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439 \u0437\u0430\u044f\u0432\u0438\u0442\u044c, \u0443\u043a\u0440\u0430\u0438\u043d\u0430 \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b, \u0440\u043e\u0441\u0441\u0438\u044f \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439","<b>Topic 2</b><br>Words: \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439, \u0437\u0435\u043b\u0435\u043d\u0441\u043a\u0438\u0439 \u0437\u0430\u044f\u0432\u0438\u0442\u044c, \u0443\u043a\u0440\u0430\u0438\u0 ...

# %% [markdown]
# Narrative #1 Nazism

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [69, 83, 124])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="161346b9-f287-4eeb-9e40-babe33ddcda5" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("161346b9-f287-4eeb-9e40-babe33ddcda5")) {                    Plotly.newPlot(                        "161346b9-f287-4eeb-9e40-babe33ddcda5",                        [{"hoverinfo":"text","hovertext":["<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0441\u0442\u0441\u043a\u0438\u0439, \u043d\u0430\u0446\u0438\u0441\u0442, \u043d\u0430\u0446\u0438\u0437\u043c, \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u0440\u0435\u0439\u0445","<b>Topic 69</b><br>Words: \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u0430\u0444\u0435\u0440\u0430, \u0430\u0444\u0440\u0438\u043a\u0430\u043d\u0441\u043a\u0438\u0439, \u043d\u0430\u0446\u0438\u0437\u043c, \u0445\u0443\u0434\u043e\u0436\u043d\u0438\u043a","<b>Topic 69</b><br>Words: \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u043d\u0430\u0446\u0438\u0437\u043c, \u043d\u0430\u0446\u0438\u0441\u0442, \u0432\u043e\u043b\u0433\u043e\u0433\u0440\u0430\u0434\u0435\u0446, \u0445\u0443\u0434\u043e\u0436\u043d\u0438\u043a","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0441\u0442, \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u043d\u0430\u0446\u0438\u0437\u043c, \u043d\u0430\u0446\u0438\u0441\u0442\u0441\u043a\u0438\u0439, \u0430\u043d\u043d\u0430","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0437\u043c, \u043d\u0430\u0446\u0438\u0441\u0442, \u0441\u0441\u0441\u0440, \u043d\u0430\u0446\u0438\u0441\u0442\u0441\u043a\u0438\u0439, \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0437\u043c, \u043d\u0430\u0446\u0438\u0441\u0442, \u043d\u0430\u0446\u0438\u0441\u0442\u0441\u043a\u0438\u0439, \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u043c\u0438\u043b\u043e\u043d","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0441\u0442, \u043d\u0430\u0446\u0438\u0441\u0442\u0441\u043a\u0438\u0439, \u043d\u0430\u0446\u0438\u0437\u043c, \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u0441\u0438\u043c\u0432\u043e\u043b\u0438\u043a\u0430","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0441\u0442\u0441\u043a\u0438\u0439, \u043d\u0430\u0446\u0438\u0441\u0442, \u043d\u0430\u0440\u0438\u0441\u043e\u0432\u0430\u0442\u044c, \u0444\u0430\u0448\u0438\u0441\u0442, \u043b\u0438\u0431\u0435\u0440\u0430\u043b","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0437\u043c, \u043d\u0430\u0446\u0438\u0441\u0442, \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u043d\u0430\u0446\u0438\u0441\u0442\u0441\u043a\u0438\u0439, \u0444\u0430\u0448\u0438\u0441\u0442","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0441\u0442, \u043d\u0430\u0446\u0438\u0437\u043c, \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u043d\u0430\u0446\u0438\u0441\u0442\u0441\u043a\u0438\u0439, \u0444\u0430\u0448\u0438\u0437\u043c","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0437\u043c, \u043d\u0430\u0446\u0438\u0441\u0442, \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u043d\u0435\u043e\u043d\u0430\u0446\u0438\u0441\u0442, \u043d\u0430\u0446\u0438\u0441\u0442\u0441\u043a\u0438\u0439","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0441\u0442, \u043d\u0435\u043e\u043d\u0430\u0446\u0438\u0441\u0442, \u043d\u0430\u0446\u0438\u0437\u043c, \u0440\u0435\u0430\u0431\u0438\u043b\u0438\u0442\u0430\u0446\u0438\u044f, \u043c\u0430\u0440\u0438\u0443\u043f\u043e\u043b\u044c","<b>Topic 69</b><br>Words: \u043d\u0430\u0446\u0438\u0437\u043c, ...

# %% [markdown]
# Narrative #8 Sanctions

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [3, 5, 7, 8, 17, 22, 40, 46, 49, 65, 82, 87, 93, 114, 134, 140, 141, 146, 154, 162, 167, 169, 172, 173, 179, 184, 185, 195, 197, 199, 200, 202, 210, 212, 214, 217, 220, 222, 229])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="436b6583-9962-4aaa-9387-5eb99713cbaa" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("436b6583-9962-4aaa-9387-5eb99713cbaa")) {                    Plotly.newPlot(                        "436b6583-9962-4aaa-9387-5eb99713cbaa",                        [{"hoverinfo":"text","hovertext":["<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0446\u0435\u043d\u0430, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439, \u0440\u043e\u0441\u043d\u0435\u0444\u0442\u044c","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0434\u043e\u0431\u044b\u0447\u0430, \u0442\u044e\u043c\u0435\u043d\u044c, \u0437\u0430\u0432\u043e\u0434, \u043f\u043e\u0436\u0430\u0440","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0446\u0435\u043d\u0430, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439, \u0430\u043e","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0440\u043e\u0441\u0442, \u0446\u0435\u043d\u0430, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u0434\u043e\u0431\u044b\u0447\u0430","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0446\u0435\u043d\u0430, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439, \u0434\u043e\u0431\u044b\u0447\u0430","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0434\u043e\u0431\u044b\u0447\u0430, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439, \u0446\u0435\u043d\u0430, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u0434\u043e\u0431\u044b\u0447\u0430, \u0446\u0435\u043d\u0430","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u0434\u043e\u0431\u044b\u0447\u0430, \u0446\u0435\u043d\u0430, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439, \u0446\u0435\u043d\u0430, \u0434\u043e\u0440\u043e\u0436\u0430\u0442\u044c","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u0438\u043c\u043f\u043e\u0440\u0442, \u043d\u0435\u0444\u0442\u044c \u0433\u0430\u0437, \u0438\u043c\u043f\u043e\u0440\u0442 \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439, \u043d\u0435\u0444\u0442\u044c \u0433\u0430\u0437, \u0438\u043c\u043f\u043e\u0440\u0442","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u044d\u043c\u0431\u0430\u0440\u0433\u043e, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439, \u043d\u043e\u0432\u0430\u043a","<b>Topic 3</b><br>Words: \u043d\u0435\u0444\u0442\u044c, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u043d\u0435\u0444\u0442\u044c, \u043d\u0435\u0444\u0442\u044f\u043d\u043e\u0439, \u0446\u0435\u043 ...

# %% [markdown]
# Narrative #7 Cold war

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [19, 28, 30, 34, 37, 47, 55, 59, 63, 71, 73, 105, 125, 139, 151, 163, 177, 190, 198, 205, 211 ])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="58d626d8-8b3f-4d31-bc5a-afb20a6586d8" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58d626d8-8b3f-4d31-bc5a-afb20a6586d8")) {                    Plotly.newPlot(                        "58d626d8-8b3f-4d31-bc5a-afb20a6586d8",                        [{"hoverinfo":"text","hovertext":["<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435, \u0432\u043e\u0439\u043d\u0430, \u0430\u044d\u0441","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u0437\u0430\u044f\u0432\u043b\u0435\u043d\u0438\u0435, \u0441\u043e\u0432\u043c\u0435\u0441\u0442\u043d\u044b\u0439, \u043e\u0440\u0443\u0436\u0438\u0435","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u0430\u0442\u043e\u043c\u043d\u044b\u0439, \u0431\u043e\u043c\u0431\u0430, \u043e\u0442\u043a\u043b\u044e\u0447\u0435\u043d\u0438\u0435 \u0440\u043e\u0441\u0441\u0438\u044f","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435, \u0430\u0442\u043e\u043c\u043d\u044b\u0439, \u0440\u0430\u0437\u043c\u0435\u0449\u0435\u043d\u0438\u0435","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435, \u0430\u0442\u043e\u043c\u043d\u044b\u0439, \u043f\u0440\u0438\u043c\u0435\u043d\u0435\u043d\u0438\u0435","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435, \u0430\u0442\u043e\u043c\u043d\u044b\u0439, \u0434\u0432\u0443\u043b\u0438\u0447\u0438\u0435","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u0430\u0442\u043e\u043c\u043d\u044b\u0439, \u043e\u0440\u0443\u0436\u0438\u0435, \u043f\u0430\u0440\u0435\u043d\u044c","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435, \u0430\u0442\u043e\u043c\u043d\u044b\u0439, \u0441\u0442\u0430\u0442\u0443\u0441","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435 \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043e\u0440\u0443\u0436\u0438\u0435 \u0441\u0448\u0430","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435, \u0430\u044d\u0441, \u0430\u0442\u043e\u043c\u043d\u044b\u0439","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435, \u0442\u043e\u043f\u043b\u0438\u0432\u043e, \u0432\u0435\u0440\u0438\u0442\u044c","<b>Topic 19</b><br>Words: \u044f\u0434\u0435\u0440\u043d\u044b\u0439, \u044f\u0434\u0435\u0440\u043d\u044b\u0439 \u043e\u0440\u0443\u0436\u0438\u0435, \u043e\u0440\u0443\u0436\u0438\u0435, \u0430\u0442\u043e\u043c\u043d\u044b\u0439, \u043c\u043e\u0447\u044c \u0438\u ...

# %% [markdown]
# Narrative #12 West not unite

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [4, 10, 15, 21, 23, 27, 32, 39, 68, 107, 121, 132, 201, 231])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="7e943d7a-fe6e-4393-9f32-ff0d47b7c6b5" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7e943d7a-fe6e-4393-9f32-ff0d47b7c6b5")) {                    Plotly.newPlot(                        "7e943d7a-fe6e-4393-9f32-ff0d47b7c6b5",                        [{"hoverinfo":"text","hovertext":["<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043a\u0430\u043d\u0446\u043b\u0435\u0440, \u043a\u0430\u043d\u0446\u043b\u0435\u0440 \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043d\u0435\u043c\u0435\u0446, \u043d\u0435\u043c\u0435\u0446\u043a\u0438\u0439","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043a\u0430\u043d\u0446\u043b\u0435\u0440, \u043a\u0430\u043d\u0446\u043b\u0435\u0440 \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u0431\u0435\u0440\u043b\u0438\u043d, \u043c\u0438\u0434 \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043f\u043e\u0441\u043e\u043b \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0431\u0435\u0440\u043b\u0438\u043d, \u043a\u0430\u043d\u0446\u043b\u0435\u0440, \u043d\u0435\u043c\u0435\u0446","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043c\u0438\u0434 \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u0433\u043b\u0430\u0432\u0430 \u043c\u0438\u0434 \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u0431\u0435\u0440\u043b\u0438\u043d, \u043a\u0430\u043d\u0446\u043b\u0435\u0440","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043d\u0435\u043c\u0435\u0446\u043a\u0438\u0439, \u0431\u0435\u0440\u043b\u0438\u043d, \u043d\u0435\u043c\u0435\u0446, \u043a\u0430\u043d\u0446\u043b\u0435\u0440","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, rt, \u043a\u0430\u043d\u0446\u043b\u0435\u0440, \u0432\u0435\u0449\u0430\u043d\u0438\u0435, \u0431\u0435\u0440\u043b\u0438\u043d","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u0440\u0435\u0447\u044c, \u0431\u0435\u0440\u043b\u0438\u043d, \u0440\u0435\u0447\u044c \u043f\u0443\u0442\u0438\u043d, \u0430\u0432\u0441\u0442\u0440\u0438\u044f","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043a\u0430\u043d\u0446\u043b\u0435\u0440, \u043a\u0430\u043d\u0446\u043b\u0435\u0440 \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043d\u0435\u043c\u0435\u0446, \u043f\u043e\u0441\u043e\u043b \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043a\u0430\u043d\u0446\u043b\u0435\u0440, \u0431\u0435\u0440\u043b\u0438\u043d, \u043d\u0435\u043c\u0435\u0446\u043a\u0438\u0439, \u0444\u0440\u0433","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043a\u0430\u043d\u0446\u043b\u0435\u0440, \u043a\u0430\u043d\u0446\u043b\u0435\u0440 \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u0431\u0435\u0440\u043b\u0438\u043d, \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f \u0437\u0430\u044f\u0432\u0438\u0442\u044c","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043a\u0430\u043d\u0446\u043b\u0435\u0440, \u043a\u0430\u043d\u0446\u043b\u0435\u0440 \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u043d\u0435\u043c\u0435\u0446\u043a\u0438\u0439, \u0431\u0435\u0440\u043b\u0438\u043d","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, welt, \u043a\u0430\u043d\u0446\u043b\u0435\u0440, \u043d\u0435\u043c\u0435\u0446\u043a\u0438\u0439, \u043f\u043e\u0441\u043e\u043b \u0443\u043a\u0440\u0430\u0438\u043d\u0430","<b>Topic 4</b><br>Words: \u0433\u0435\u0440\u043c\u0430\u043d\u0438\u044f, \u04 ...

# %% [markdown]
# Narrative #9 Russian values

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics = [36, 53, 67, 76, 84, 86, 120, 142, 143, 150, 152, 155, 156, 168, 191, 196, 227])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6c5f7c2f-4cf6-4113-a182-f3ed7130d8d7" class="plotly-graph-div" style="height:450px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6c5f7c2f-4cf6-4113-a182-f3ed7130d8d7")) {                    Plotly.newPlot(                        "6c5f7c2f-4cf6-4113-a182-f3ed7130d8d7",                        [{"hoverinfo":"text","hovertext":["<b>Topic 36</b><br>Words: \u043b\u0438\u043a\u0432\u0438\u0434\u0430\u0446\u0438\u044f, \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u043f\u0430\u043c\u044f\u0442\u044c, \u0432\u043e\u0438\u043d, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439","<b>Topic 36</b><br>Words: \u043a\u043e\u0441\u0442\u0440\u043e\u043c\u0430, \u0443\u0431\u0438\u0442\u044b\u0439, \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u0434\u0435\u0432\u043e\u0447\u043a\u0430, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u043f\u0430\u043c\u044f\u0442\u044c, \u0432\u043e\u0438\u043d, \u0441\u043e\u043b\u0434\u0430\u0442, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u043f\u0430\u043c\u044f\u0442\u044c, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439, \u0432\u043e\u0438\u043d, \u043c\u043e\u0433\u0438\u043b\u0430","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u043f\u0430\u043c\u044f\u0442\u044c, \u0446\u0432\u0435\u0442\u043e\u043a, \u0432\u043e\u0437\u043b\u043e\u0436\u0438\u0442\u044c, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u043f\u0430\u043c\u044f\u0442\u044c, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439, \u043f\u043e\u0447\u0442\u0438\u0442\u044c, \u0432\u043e\u0438\u043d","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u043c\u043e\u0433\u0438\u043b\u0430, \u043f\u0430\u043c\u044f\u0442\u044c, \u0432\u043e\u0437\u043b\u043e\u0436\u0438\u0442\u044c, \u0432\u043e\u0438\u043d","<b>Topic 36</b><br>Words: \u0432\u043e\u0438\u043d, \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u043f\u0430\u043c\u044f\u0442\u044c, \u043f\u043e\u0447\u0442\u0438\u0442\u044c, \u043f\u043e\u0447\u0442\u0438\u0442\u044c \u043f\u0430\u043c\u044f\u0442\u044c","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u0432\u043e\u0437\u043b\u043e\u0436\u0438\u0442\u044c, \u043c\u043e\u0433\u0438\u043b\u0430, \u0432\u043e\u0438\u043d, \u043d\u0435\u0438\u0437\u0432\u0435\u0441\u0442\u043d\u044b\u0439","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u044c, \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u043f\u043e\u0447\u0442\u0438\u0442\u044c, \u043f\u043e\u0447\u0442\u0438\u0442\u044c \u043f\u0430\u043c\u044f\u0442\u044c, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u0432\u043e\u0438\u043d, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439, \u043f\u0430\u043c\u044f\u0442\u044c, \u0446\u0432\u0435\u0442\u043e\u043a","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u0432\u043e\u0438\u043d, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439, \u0433\u0440\u0435\u0446\u0438\u044f, \u043f\u0430\u043c\u044f\u0442\u044c","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u0441\u043e\u0432\u0435\u0442\u0441\u043a\u0438\u0439, \u0432\u043e\u0438\u043d, \u043f\u0430\u043c\u044f\u0442\u044c, \u043f\u043e\u0447\u0442\u0438\u0442\u044c","<b>Topic 36</b><br>Words: \u043f\u0430\u043c\u044f\u0442\u043d\u0438\u043a, \u0432\u043e\u0438\u043d, \u043f\u0430\u043c\u044f\u0442\u044c, \u04 ...

# %% [markdown]
# All narratives

# %%
topics_rel = [69, 83, 124, 2, 60, 135, 166, 1, 90, 95, 96, 112, 117, 122, 161, 178, 183, 194, 213, 228, 91, 136, 157, 160, 19, 28, 30, 34, 37, 47, 55, 59, 63, 71, 73, 105, 125, 139, 151, 163, 177, 190, 198, 205, 211, 3, 5, 7, 8, 17, 22, 40, 46, 49, 65, 82, 87, 93, 114, 134, 140, 141, 146, 154, 162, 167, 169, 172, 173, 179, 184, 185, 195, 197, 199, 200, 202, 210, 212, 214, 217, 220, 222, 229, 36, 53, 67, 76, 84, 86, 120, 142, 143, 150, 152, 155, 156, 168, 191, 196, 227, 14, 57, 61, 104, 110, 159, 207, 6, 13, 38, 85, 92, 100, 149, 174, 216, 4, 10, 15, 21, 23, 27, 32, 39, 68, 107, 121, 132, 201, 231, 12, 33, 94, 99, 145, 181, 193, 11, 41, 180, 0, 25, 31, 64, 80, 106, 113, 118, 144, 158, 164, 175, 225, 230]

# %%
topic_model.visualize_topics_over_time(topics_over_time, topics=topics_rel, height=700)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1ff666c2-f2a7-4e66-8466-505988f1023d" class="plotly-graph-div" style="height:700px; width:1250px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ff666c2-f2a7-4e66-8466-505988f1023d")) {                    Plotly.newPlot(                        "1ff666c2-f2a7-4e66-8466-505988f1023d",                        [{"hoverinfo":"text","hovertext":["<b>Topic 0</b><br>Words: \u043f\u0443\u0442\u0438\u043d \u0431\u0430\u0439\u0434\u0435\u043d, \u0433\u0430\u0437, \u0442\u0440\u0430\u043d\u0437\u0438\u0442, \u0432\u0437\u0440\u044b\u0432, \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f","<b>Topic 0</b><br>Words: \u0442\u0440\u0430\u043d\u0437\u0438\u0442, \u0433\u0430\u0437, \u0440\u043e\u0441\u0441\u0438\u0439\u0441\u043a\u0438\u0439 \u0433\u0430\u0437, \u0432\u043e\u0440\u043e\u0432\u0441\u0442\u0432\u043e, \u0441\u043b\u043e\u0432\u0430\u043a\u0438\u044f","<b>Topic 0</b><br>Words: \u0447\u0435\u043c\u043f\u0438\u043e\u043d\u0430\u0442, \u0444\u0438\u0433\u0443\u0440\u0438\u0441\u0442, \u0432\u043d\u0435\u0437\u0430\u043f\u043d\u044b\u0439, \u0432\u0437\u0440\u044b\u0432, \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f","<b>Topic 0</b><br>Words: \u0431\u043b\u0438\u043d\u043a\u0435\u043d, \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u043f\u043e\u0440\u043e\u0448\u0435\u043d\u043a\u043e, \u043f\u0435\u0440\u0435\u0433\u043e\u0432\u043e\u0440\u044b \u043b\u0430\u0432\u0440\u043e\u0432, \u043b\u0430\u0432\u0440\u043e\u0432","<b>Topic 0</b><br>Words: \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u0434\u0436\u043e\u043d\u0441\u043e\u043d, \u0432\u0435\u043b\u0438\u043a\u043e\u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0433\u043b\u0430\u0432\u0430","<b>Topic 0</b><br>Words: \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u0434\u0436\u043e\u043d\u0441\u043e\u043d, \u043c\u0430\u043a\u0440\u043e\u043d, \u043f\u0443\u0442\u0438\u043d \u043c\u0430\u043a\u0440\u043e\u043d, \u0442\u0440\u0430\u043d\u0437\u0438\u0442","<b>Topic 0</b><br>Words: \u043c\u0430\u043a\u0440\u043e\u043d, \u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f, \u043f\u0443\u0442\u0438\u043d \u043c\u0430\u043a\u0440\u043e\u043d, \u0432\u0441\u0442\u0440\u0435\u0447\u0430, \u0432\u0435\u043b\u0438\u043a\u043e\u0431\u0440\u0438\u0442\u0430\u043d\u0438\u044f","<b>Topic 0</b><br>Words: \u043e\u0431\u0441\u0442\u0440\u0435\u043b, \u0432\u0437\u0440\u044b\u0432, \u043e\u0431\u0441\u0442\u0440\u0435\u043b\u044f\u0442\u044c, \u043b\u0443\u0433\u0430\u043d\u0441\u043a, \u0434\u043e\u043d\u0431\u0430\u0441\u0441","<b>Topic 0</b><br>Words: \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f, \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u043e\u0431\u0441\u0442\u0440\u0435\u043b, \u043e\u0431\u0441\u0442\u0440\u0435\u043b\u044f\u0442\u044c, \u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f","<b>Topic 0</b><br>Words: \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f, \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0432\u043e\u0435\u043d\u043d\u044b\u0439, \u043c\u0438\u043d\u043e\u0431\u043e\u0440\u043e\u043d\u044b","<b>Topic 0</b><br>Words: \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f \u0443\u043a\u0440\u0430\u0438\u043d\u0430, \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f, \u043f\u043e\u0433\u0438\u0431\u043d\u0443\u0442\u044c, \u043e\u0431\u0441\u0442\u0440\u0435\u043b\u044f\u0442\u044c, \u0432\u0440\u0435\u043c\u044f \u0441\u043f\u0435\u0446\u043e\u043f\u0435\u0440\u0430\u0446\u0438\u044f","<b>Topic 0</b><br> ...

# %% [markdown]
# Mapping

# %%
topic_model.visualize_documents(titles, topics=topics_map, hide_document_hover=False, hide_annotations=False, width=2000).write_html("doc_viz.html")

# %%
topics_over_time.to_csv("topics_time.csv")
